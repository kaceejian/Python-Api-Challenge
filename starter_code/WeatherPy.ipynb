# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# YOUR KEY HERE!

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = list(zip(lats, lngs))
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 634

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base = 'https://api.openweathermap.org/data/2.5/weather'
weather_api_key = "ebf7377c80a9c88f36d20bc316cc7740"
print("Beginning data retrieval")
print('-' * 20)
number = 0
results = []
for city in (cities):
    d = {'q': city, 'appid': weather_api_key}
    r = requests.get(base, params=d)
    data = r.json()
    if data['cod'] == 200:
        print("Processing Record", number + 1, 'of Set 1', '|', city)
        info = {'City': city, 'Lat': data['coord']['lat'], 'Lng': data['coord']['lon'], 'Max Temp': data['main']['temp_max'],
                'Humidity': data['main']['humidity'], 'Cloudiness': data['clouds']['all'],
                'Wind Speed': data['wind']['speed'], 'Country': data['sys']['country'], 'Date': data['dt']}
        results.append(info)
        number += 1
    else:
        print('City not found. Skipping...')

    
# def even(dog):
#     if dog % 2 == 0:
#         print('number is even')
#     else:
#         print('number is odd')
# even(11)
# Out:
# Beginning data retrieval
# --------------------
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | atasu
# Processing Record 3 of Set 1 | lavrentiya
# Processing Record 4 of Set 1 | codrington
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | taunggyi
# Processing Record 7 of Set 1 | lasa
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | khatanga
# Processing Record 10 of Set 1 | cherskiy
# Processing Record 11 of Set 1 | kiama
# Processing Record 12 of Set 1 | peleduy
# City not found. Skipping...
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | nanortalik
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | pilar
# Processing Record 18 of Set 1 | pinawa
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | mechanicsville
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | bontoc
# Processing Record 24 of Set 1 | kisangani
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | kudahuvadhoo
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | cocobeach
# Processing Record 30 of Set 1 | ostrovnoy
# Processing Record 31 of Set 1 | kidal
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | visnes
# Processing Record 34 of Set 1 | valdosta
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | copiapo
# Processing Record 37 of Set 1 | talcher
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | mandalgovi
# Processing Record 40 of Set 1 | junin
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | severobaykalsk
# Processing Record 43 of Set 1 | ahipara
# Processing Record 44 of Set 1 | korla
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | sambava
# Processing Record 47 of Set 1 | yatou
# Processing Record 48 of Set 1 | izberbash
# Processing Record 49 of Set 1 | half moon bay
# Processing Record 50 of Set 1 | hobart
# Processing Record 51 of Set 1 | iqaluit
# City not found. Skipping...
# Processing Record 52 of Set 1 | meulaboh
# Processing Record 53 of Set 1 | mahebourg
# Processing Record 54 of Set 1 | rivne
# Processing Record 55 of Set 1 | yima
# Processing Record 56 of Set 1 | qaanaaq
# Processing Record 57 of Set 1 | ridgecrest
# Processing Record 58 of Set 1 | hithadhoo
# Processing Record 59 of Set 1 | coquimbo
# Processing Record 60 of Set 1 | rafaela
# Processing Record 61 of Set 1 | vaini
# Processing Record 62 of Set 1 | baykit
# Processing Record 63 of Set 1 | yeppoon
# Processing Record 64 of Set 1 | yarada
# Processing Record 65 of Set 1 | dikson
# Processing Record 66 of Set 1 | hermanus
# Processing Record 67 of Set 1 | beloha
# Processing Record 68 of Set 1 | port alfred
# Processing Record 69 of Set 1 | ulladulla
# Processing Record 70 of Set 1 | esperance
# Processing Record 71 of Set 1 | la ronge
# Processing Record 72 of Set 1 | mount isa
# Processing Record 73 of Set 1 | georgetown
# Processing Record 74 of Set 1 | chervonohryhorivka
# Processing Record 75 of Set 1 | laguna
# Processing Record 76 of Set 1 | ulety
# Processing Record 77 of Set 1 | castro
# Processing Record 78 of Set 1 | calvinia
# Processing Record 79 of Set 1 | sungaipenuh
# Processing Record 80 of Set 1 | saskylakh
# Processing Record 81 of Set 1 | west monroe
# Processing Record 82 of Set 1 | barrow
# Processing Record 83 of Set 1 | padang
# Processing Record 84 of Set 1 | solnechnyy
# Processing Record 85 of Set 1 | vilyuysk
# Processing Record 86 of Set 1 | kapaa
# Processing Record 87 of Set 1 | beboto
# Processing Record 88 of Set 1 | vila velha
# Processing Record 89 of Set 1 | chokurdakh
# Processing Record 90 of Set 1 | oranjemund
# Processing Record 91 of Set 1 | port elizabeth
# Processing Record 92 of Set 1 | paita
# Processing Record 93 of Set 1 | kohlu
# Processing Record 94 of Set 1 | vostok
# City not found. Skipping...
# Processing Record 95 of Set 1 | sibu
# Processing Record 96 of Set 1 | asau
# Processing Record 97 of Set 1 | taoudenni
# Processing Record 98 of Set 1 | laje
# Processing Record 99 of Set 1 | pringsewu
# Processing Record 100 of Set 1 | ambunti
# Processing Record 101 of Set 1 | margate
# Processing Record 102 of Set 1 | new norfolk
# Processing Record 103 of Set 1 | yellowknife
# Processing Record 104 of Set 1 | mar del plata
# Processing Record 105 of Set 1 | poya
# City not found. Skipping...
# Processing Record 106 of Set 1 | vardo
# Processing Record 107 of Set 1 | barra patuca
# City not found. Skipping...
# Processing Record 108 of Set 1 | cascais
# Processing Record 109 of Set 1 | peniche
# Processing Record 110 of Set 1 | bethel
# Processing Record 111 of Set 1 | albany
# Processing Record 112 of Set 1 | ancud
# City not found. Skipping...
# Processing Record 113 of Set 1 | richards bay
# Processing Record 114 of Set 1 | kruisfontein
# Processing Record 115 of Set 1 | esso
# Processing Record 116 of Set 1 | maltahohe
# Processing Record 117 of Set 1 | ayagoz
# Processing Record 118 of Set 1 | kirakira
# Processing Record 119 of Set 1 | pisco
# Processing Record 120 of Set 1 | ponta do sol
# Processing Record 121 of Set 1 | bestobe
# Processing Record 122 of Set 1 | kapit
# Processing Record 123 of Set 1 | talnakh
# City not found. Skipping...
# Processing Record 124 of Set 1 | lhokseumawe
# Processing Record 125 of Set 1 | cayenne
# City not found. Skipping...
# Processing Record 126 of Set 1 | antakya
# Processing Record 127 of Set 1 | ewa beach
# Processing Record 128 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 129 of Set 1 | hilo
# Processing Record 130 of Set 1 | camopi
# Processing Record 131 of Set 1 | puerto madryn
# Processing Record 132 of Set 1 | kodiak
# Processing Record 133 of Set 1 | chapais
# City not found. Skipping...
# Processing Record 134 of Set 1 | brae
# Processing Record 135 of Set 1 | umm kaddadah
# Processing Record 136 of Set 1 | saint-francois
# Processing Record 137 of Set 1 | saint anthony
# Processing Record 138 of Set 1 | ilulissat
# Processing Record 139 of Set 1 | longyearbyen
# Processing Record 140 of Set 1 | san patricio
# Processing Record 141 of Set 1 | show low
# Processing Record 142 of Set 1 | namatanai
# City not found. Skipping...
# Processing Record 143 of Set 1 | boromo
# City not found. Skipping...
# Processing Record 144 of Set 1 | bahir dar
# Processing Record 145 of Set 1 | bathsheba
# Processing Record 146 of Set 1 | provideniya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 147 of Set 1 | abha
# Processing Record 148 of Set 1 | san jeronimo
# City not found. Skipping...
# Processing Record 149 of Set 1 | bundaberg
# Processing Record 150 of Set 1 | nushki
# Processing Record 151 of Set 1 | saint-joseph
# Processing Record 152 of Set 1 | muros
# Processing Record 153 of Set 1 | srednekolymsk
# Processing Record 154 of Set 1 | yulara
# Processing Record 155 of Set 1 | micheweni
# City not found. Skipping...
# Processing Record 156 of Set 1 | lorengau
# Processing Record 157 of Set 1 | geraldton
# Processing Record 158 of Set 1 | comodoro rivadavia
# Processing Record 159 of Set 1 | the valley
# Processing Record 160 of Set 1 | nelson bay
# Processing Record 161 of Set 1 | elliot
# City not found. Skipping...
# Processing Record 162 of Set 1 | maningrida
# Processing Record 163 of Set 1 | araouane
# Processing Record 164 of Set 1 | havre-saint-pierre
# Processing Record 165 of Set 1 | jamestown
# Processing Record 166 of Set 1 | ginda
# Processing Record 167 of Set 1 | fulton
# Processing Record 168 of Set 1 | tongliao
# Processing Record 169 of Set 1 | odweyne
# City not found. Skipping...
# Processing Record 170 of Set 1 | tashla
# Processing Record 171 of Set 1 | joshimath
# Processing Record 172 of Set 1 | venice
# Processing Record 173 of Set 1 | kahului
# Processing Record 174 of Set 1 | bontang
# Processing Record 175 of Set 1 | torbay
# Processing Record 176 of Set 1 | haines junction
# Processing Record 177 of Set 1 | salalah
# City not found. Skipping...
# Processing Record 178 of Set 1 | bataipora
# Processing Record 179 of Set 1 | xinzhi
# Processing Record 180 of Set 1 | pevek
# Processing Record 181 of Set 1 | ucluelet
# Processing Record 182 of Set 1 | sisimiut
# Processing Record 183 of Set 1 | kempsey
# Processing Record 184 of Set 1 | dingle
# Processing Record 185 of Set 1 | vaitape
# Processing Record 186 of Set 1 | suclayin
# Processing Record 187 of Set 1 | auki
# Processing Record 188 of Set 1 | trat
# Processing Record 189 of Set 1 | sao gabriel
# Processing Record 190 of Set 1 | fort-shevchenko
# Processing Record 191 of Set 1 | bud
# Processing Record 192 of Set 1 | puerto ayora
# Processing Record 193 of Set 1 | sitka
# City not found. Skipping...
# Processing Record 194 of Set 1 | darnah
# Processing Record 195 of Set 1 | port lincoln
# Processing Record 196 of Set 1 | kupino
# Processing Record 197 of Set 1 | praia grande
# Processing Record 198 of Set 1 | marathon
# Processing Record 199 of Set 1 | klaksvik
# Processing Record 200 of Set 1 | abu dhabi
# City not found. Skipping...
# Processing Record 201 of Set 1 | nizhnekamsk
# Processing Record 202 of Set 1 | mata
# Processing Record 203 of Set 1 | raudeberg
# Processing Record 204 of Set 1 | narsaq
# Processing Record 205 of Set 1 | bilma
# Processing Record 206 of Set 1 | katsuura
# Processing Record 207 of Set 1 | saint-philippe
# Processing Record 208 of Set 1 | hasaki
# Processing Record 209 of Set 1 | karratha
# Processing Record 210 of Set 1 | panaba
# Processing Record 211 of Set 1 | prince rupert
# Processing Record 212 of Set 1 | pacific grove
# Processing Record 213 of Set 1 | saint-ambroise
# Processing Record 214 of Set 1 | naryan-mar
# Processing Record 215 of Set 1 | surin
# Processing Record 216 of Set 1 | tiksi
# Processing Record 217 of Set 1 | zakamensk
# City not found. Skipping...
# Processing Record 218 of Set 1 | ternate
# Processing Record 219 of Set 1 | port hardy
# Processing Record 220 of Set 1 | sidi ali
# Processing Record 221 of Set 1 | cidreira
# City not found. Skipping...
# Processing Record 222 of Set 1 | kenai
# Processing Record 223 of Set 1 | oyama
# Processing Record 224 of Set 1 | dubrovka
# Processing Record 225 of Set 1 | ouesso
# Processing Record 226 of Set 1 | maragogi
# Processing Record 227 of Set 1 | bambous virieux
# Processing Record 228 of Set 1 | damara
# Processing Record 229 of Set 1 | hami
# Processing Record 230 of Set 1 | udachnyy
# Processing Record 231 of Set 1 | acajutla
# Processing Record 232 of Set 1 | quelimane
# Processing Record 233 of Set 1 | bilibino
# Processing Record 234 of Set 1 | bambamarca
# Processing Record 235 of Set 1 | stornoway
# Processing Record 236 of Set 1 | cockburn town
# Processing Record 237 of Set 1 | kolda
# Processing Record 238 of Set 1 | faya
# Processing Record 239 of Set 1 | east london
# City not found. Skipping...
# Processing Record 240 of Set 1 | ritchie
# Processing Record 241 of Set 1 | college
# Processing Record 242 of Set 1 | envira
# Processing Record 243 of Set 1 | severo-kurilsk
# City not found. Skipping...
# Processing Record 244 of Set 1 | lagoa
# Processing Record 245 of Set 1 | port macquarie
# Processing Record 246 of Set 1 | sistranda
# Processing Record 247 of Set 1 | soc trang
# City not found. Skipping...
# Processing Record 248 of Set 1 | pembroke
# Processing Record 249 of Set 1 | pemba
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 250 of Set 1 | tenenkou
# Processing Record 251 of Set 1 | panzhihua
# Processing Record 252 of Set 1 | vagur
# Processing Record 253 of Set 1 | cabo san lucas
# Processing Record 254 of Set 1 | alice springs
# Processing Record 255 of Set 1 | dengzhou
# Processing Record 256 of Set 1 | hofn
# Processing Record 257 of Set 1 | kaitangata
# Processing Record 258 of Set 1 | san andres
# Processing Record 259 of Set 1 | nyurba
# Processing Record 260 of Set 1 | grindavik
# Processing Record 261 of Set 1 | port blair
# Processing Record 262 of Set 1 | saldanha
# Processing Record 263 of Set 1 | san ignacio
# Processing Record 264 of Set 1 | nikolskoye
# Processing Record 265 of Set 1 | namtsy
# Processing Record 266 of Set 1 | thompson
# City not found. Skipping...
# Processing Record 267 of Set 1 | visby
# Processing Record 268 of Set 1 | concepcion del uruguay
# Processing Record 269 of Set 1 | chuy
# Processing Record 270 of Set 1 | porto novo
# Processing Record 271 of Set 1 | oksfjord
# Processing Record 272 of Set 1 | luderitz
# Processing Record 273 of Set 1 | mirador
# Processing Record 274 of Set 1 | olinda
# Processing Record 275 of Set 1 | ringebu
# Processing Record 276 of Set 1 | luang prabang
# Processing Record 277 of Set 1 | kloulklubed
# Processing Record 278 of Set 1 | los llanos de aridane
# Processing Record 279 of Set 1 | vanimo
# Processing Record 280 of Set 1 | jeremoabo
# City not found. Skipping...
# Processing Record 281 of Set 1 | shenxian
# Processing Record 282 of Set 1 | whitecourt
# Processing Record 283 of Set 1 | brantford
# City not found. Skipping...
# Processing Record 284 of Set 1 | sao filipe
# Processing Record 285 of Set 1 | puerto baquerizo moreno
# Processing Record 286 of Set 1 | manjeshwar
# Processing Record 287 of Set 1 | malakal
# Processing Record 288 of Set 1 | marfino
# Processing Record 289 of Set 1 | manavalakurichi
# Processing Record 290 of Set 1 | leningradskiy
# Processing Record 291 of Set 1 | nagtipunan
# Processing Record 292 of Set 1 | la asuncion
# Processing Record 293 of Set 1 | souillac
# Processing Record 294 of Set 1 | itaituba
# Processing Record 295 of Set 1 | robertsport
# Processing Record 296 of Set 1 | sukhumi
# Processing Record 297 of Set 1 | bengkulu
# Processing Record 298 of Set 1 | banamba
# Processing Record 299 of Set 1 | sao joao da barra
# City not found. Skipping...
# Processing Record 300 of Set 1 | mareeba
# Processing Record 301 of Set 1 | lakatoro
# Processing Record 302 of Set 1 | bakchar
# Processing Record 303 of Set 1 | chisec
# Processing Record 304 of Set 1 | senneterre
# Processing Record 305 of Set 1 | sinnamary
# Processing Record 306 of Set 1 | jumla
# Processing Record 307 of Set 1 | vavozh
# Processing Record 308 of Set 1 | tual
# Processing Record 309 of Set 1 | hamilton
# City not found. Skipping...
# Processing Record 310 of Set 1 | beisfjord
# Processing Record 311 of Set 1 | kalagarh
# Processing Record 312 of Set 1 | siniscola
# Processing Record 313 of Set 1 | arraial do cabo
# Processing Record 314 of Set 1 | lulea
# Processing Record 315 of Set 1 | muroto
# Processing Record 316 of Set 1 | faanui
# City not found. Skipping...
# Processing Record 317 of Set 1 | saint george
# Processing Record 318 of Set 1 | namibe
# Processing Record 319 of Set 1 | orel-izumrud
# Processing Record 320 of Set 1 | kungurtug
# Processing Record 321 of Set 1 | jibuti
# Processing Record 322 of Set 1 | tura
# Processing Record 323 of Set 1 | olbia
# Processing Record 324 of Set 1 | sri aman
# Processing Record 325 of Set 1 | chunskiy
# Processing Record 326 of Set 1 | whitehorse
# Processing Record 327 of Set 1 | komsomolskiy
# Processing Record 328 of Set 1 | north bend
# Processing Record 329 of Set 1 | airai
# Processing Record 330 of Set 1 | talara
# Processing Record 331 of Set 1 | seydi
# Processing Record 332 of Set 1 | trairi
# Processing Record 333 of Set 1 | khoy
# Processing Record 334 of Set 1 | san juan bautista
# City not found. Skipping...
# Processing Record 335 of Set 1 | lai
# Processing Record 336 of Set 1 | baijiantan
# Processing Record 337 of Set 1 | beringovskiy
# Processing Record 338 of Set 1 | klyuchi
# Processing Record 339 of Set 1 | ayorou
# Processing Record 340 of Set 1 | okhotsk
# Processing Record 341 of Set 1 | te anau
# Processing Record 342 of Set 1 | biak
# Processing Record 343 of Set 1 | matagami
# Processing Record 344 of Set 1 | novopokrovka
# Processing Record 345 of Set 1 | aswan
# Processing Record 346 of Set 1 | basco
# Processing Record 347 of Set 1 | bereda
# Processing Record 348 of Set 1 | conceicao do araguaia
# Processing Record 349 of Set 1 | trincomalee
# Processing Record 350 of Set 1 | livingston
# Processing Record 351 of Set 1 | huarmey
# Processing Record 352 of Set 1 | iquitos
# Processing Record 353 of Set 1 | anadyr
# Processing Record 354 of Set 1 | ignatovka
# Processing Record 355 of Set 1 | lebu
# Processing Record 356 of Set 1 | charyshskoye
# Processing Record 357 of Set 1 | virginia beach
# Processing Record 358 of Set 1 | caravelas
# Processing Record 359 of Set 1 | kalianget
# Processing Record 360 of Set 1 | bosaso
# City not found. Skipping...
# Processing Record 361 of Set 1 | harriston
# Processing Record 362 of Set 1 | evensk
# Processing Record 363 of Set 1 | bizhbulyak
# Processing Record 364 of Set 1 | taltal
# Processing Record 365 of Set 1 | victoria
# Processing Record 366 of Set 1 | rio gallegos
# Processing Record 367 of Set 1 | morro bay
# Processing Record 368 of Set 1 | buchanan
# Processing Record 369 of Set 1 | manono
# Processing Record 370 of Set 1 | inhambane
# Processing Record 371 of Set 1 | jizan
# Processing Record 372 of Set 1 | sur
# Processing Record 373 of Set 1 | latung
# Processing Record 374 of Set 1 | togur
# Processing Record 375 of Set 1 | san cristobal
# Processing Record 376 of Set 1 | nome
# Processing Record 377 of Set 1 | khandyga
# Processing Record 378 of Set 1 | mullovka
# Processing Record 379 of Set 1 | cachira
# Processing Record 380 of Set 1 | porto santo
# Processing Record 381 of Set 1 | casablanca
# Processing Record 382 of Set 1 | mount gambier
# Processing Record 383 of Set 1 | tiarei
# Processing Record 384 of Set 1 | fortuna
# Processing Record 385 of Set 1 | abdanan
# Processing Record 386 of Set 1 | luanda
# Processing Record 387 of Set 1 | praia da vitoria
# Processing Record 388 of Set 1 | pouembout
# Processing Record 389 of Set 1 | seoul
# Processing Record 390 of Set 1 | antalaha
# Processing Record 391 of Set 1 | petrolina
# Processing Record 392 of Set 1 | moundsville
# Processing Record 393 of Set 1 | reserva
# Processing Record 394 of Set 1 | atar
# Processing Record 395 of Set 1 | anloga
# Processing Record 396 of Set 1 | cabo rojo
# Processing Record 397 of Set 1 | baishishan
# Processing Record 398 of Set 1 | waingapu
# City not found. Skipping...
# Processing Record 399 of Set 1 | mimoso do sul
# Processing Record 400 of Set 1 | janauba
# Processing Record 401 of Set 1 | konispol
# Processing Record 402 of Set 1 | sechura
# Processing Record 403 of Set 1 | kasempa
# Processing Record 404 of Set 1 | aripuana
# Processing Record 405 of Set 1 | kazachinskoye
# Processing Record 406 of Set 1 | makokou
# Processing Record 407 of Set 1 | kitaibaraki
# Processing Record 408 of Set 1 | coahuayana
# City not found. Skipping...
# Processing Record 409 of Set 1 | tortoli
# Processing Record 410 of Set 1 | paamiut
# Processing Record 411 of Set 1 | obidos
# Processing Record 412 of Set 1 | pangnirtung
# Processing Record 413 of Set 1 | batagay-alyta
# Processing Record 414 of Set 1 | lichinga
# Processing Record 415 of Set 1 | hanzhong
# Processing Record 416 of Set 1 | teya
# Processing Record 417 of Set 1 | birjand
# Processing Record 418 of Set 1 | bam
# Processing Record 419 of Set 1 | shubarshi
# Processing Record 420 of Set 1 | yantal
# Processing Record 421 of Set 1 | terre haute
# Processing Record 422 of Set 1 | mattru
# Processing Record 423 of Set 1 | snasa
# Processing Record 424 of Set 1 | fairbanks
# Processing Record 425 of Set 1 | nivala
# Processing Record 426 of Set 1 | sandwick
# Processing Record 427 of Set 1 | isangel
# Processing Record 428 of Set 1 | beira
# Processing Record 429 of Set 1 | burlington
# Processing Record 430 of Set 1 | rundu
# Processing Record 431 of Set 1 | monrovia
# Processing Record 432 of Set 1 | nantong
# Processing Record 433 of Set 1 | rincon
# Processing Record 434 of Set 1 | egvekinot
# Processing Record 435 of Set 1 | shimoda
# Processing Record 436 of Set 1 | duluth
# City not found. Skipping...
# Processing Record 437 of Set 1 | yingcheng
# Processing Record 438 of Set 1 | chara
# Processing Record 439 of Set 1 | sungairaya
# Processing Record 440 of Set 1 | taree
# City not found. Skipping...
# Processing Record 441 of Set 1 | olutanga
# Processing Record 442 of Set 1 | sharjah
# Processing Record 443 of Set 1 | clyde river
# Processing Record 444 of Set 1 | urucara
# Processing Record 445 of Set 1 | dergachi
# Processing Record 446 of Set 1 | jalu
# Processing Record 447 of Set 1 | svetlogorsk
# City not found. Skipping...
# Processing Record 448 of Set 1 | kalmunai
# Processing Record 449 of Set 1 | sale
# City not found. Skipping...
# Processing Record 450 of Set 1 | pathein
# Processing Record 451 of Set 1 | avera
# Processing Record 452 of Set 1 | vao
# Processing Record 453 of Set 1 | varberg
# Processing Record 454 of Set 1 | ahtopol
# Processing Record 455 of Set 1 | yeniseysk
# Processing Record 456 of Set 1 | nedjo
# Processing Record 457 of Set 1 | jackson
# Processing Record 458 of Set 1 | martapura
# Processing Record 459 of Set 1 | morant bay
# Processing Record 460 of Set 1 | stawell
# Processing Record 461 of Set 1 | achacachi
# Processing Record 462 of Set 1 | savannah bight
# Processing Record 463 of Set 1 | poum
# Processing Record 464 of Set 1 | macas
# Processing Record 465 of Set 1 | ambilobe
# Processing Record 466 of Set 1 | portland
# Processing Record 467 of Set 1 | karpathos
# Processing Record 468 of Set 1 | chor
# Processing Record 469 of Set 1 | bethal
# Processing Record 470 of Set 1 | amlame
# Processing Record 471 of Set 1 | montorio al vomano
# Processing Record 472 of Set 1 | buraydah
# Processing Record 473 of Set 1 | collie
# Processing Record 474 of Set 1 | chepareria
# Processing Record 475 of Set 1 | gua musang
# Processing Record 476 of Set 1 | santa rosa
# Processing Record 477 of Set 1 | wanning
# Processing Record 478 of Set 1 | belmonte
# Processing Record 479 of Set 1 | imperial
# Processing Record 480 of Set 1 | kollo
# Processing Record 481 of Set 1 | camacha
# Processing Record 482 of Set 1 | hay river
# Processing Record 483 of Set 1 | islahiye
# Processing Record 484 of Set 1 | goderich
# Processing Record 485 of Set 1 | hattiesburg
# Processing Record 486 of Set 1 | sheridan
# Processing Record 487 of Set 1 | cheremukhovo
# Processing Record 488 of Set 1 | carauari
# Processing Record 489 of Set 1 | catia la mar
# Processing Record 490 of Set 1 | alexandria
# Processing Record 491 of Set 1 | rumonge
# Processing Record 492 of Set 1 | mahajanga
# Processing Record 493 of Set 1 | purificacion
# Processing Record 494 of Set 1 | panarukan
# Processing Record 495 of Set 1 | puerto quijarro
# Processing Record 496 of Set 1 | tautira
# Processing Record 497 of Set 1 | pandan
# Processing Record 498 of Set 1 | were ilu
# Processing Record 499 of Set 1 | alofi
# Processing Record 500 of Set 1 | pietarsaari
# Processing Record 501 of Set 1 | conde
# Processing Record 502 of Set 1 | dryden
# Processing Record 503 of Set 1 | mweka
# Processing Record 504 of Set 1 | mananara
# Processing Record 505 of Set 1 | kamaishi
# Processing Record 506 of Set 1 | chardara
# City not found. Skipping...
# Processing Record 507 of Set 1 | shush
# Processing Record 508 of Set 1 | verkhnyaya inta
# Processing Record 509 of Set 1 | marsa matruh
# Processing Record 510 of Set 1 | salinopolis
# Processing Record 511 of Set 1 | severo-yeniseyskiy
# Processing Record 512 of Set 1 | paso de los toros
# Processing Record 513 of Set 1 | sola
# Processing Record 514 of Set 1 | batemans bay
# Processing Record 515 of Set 1 | constitucion
# Processing Record 516 of Set 1 | kavieng
# Processing Record 517 of Set 1 | manggar
# Processing Record 518 of Set 1 | dwarka
# City not found. Skipping...
# Processing Record 519 of Set 1 | porto walter
# Processing Record 520 of Set 1 | galesong
# Processing Record 521 of Set 1 | honiara
# Processing Record 522 of Set 1 | pemangkat
# Processing Record 523 of Set 1 | loukhi
# City not found. Skipping...
# Processing Record 524 of Set 1 | dinguiraye
# Processing Record 525 of Set 1 | kokopo
# Processing Record 526 of Set 1 | khromtau
# City not found. Skipping...
# Processing Record 527 of Set 1 | laramie
# Processing Record 528 of Set 1 | quatre cocos
# Processing Record 529 of Set 1 | yelan
# Processing Record 530 of Set 1 | troitskoye
# Processing Record 531 of Set 1 | horadiz
# Processing Record 532 of Set 1 | temirtau
# Processing Record 533 of Set 1 | reconquista
# Processing Record 534 of Set 1 | clarksburg
# Processing Record 535 of Set 1 | hambantota
# Processing Record 536 of Set 1 | kavaratti
# Processing Record 537 of Set 1 | west wendover
# Processing Record 538 of Set 1 | bandarbeyla
# Processing Record 539 of Set 1 | palauig
# Processing Record 540 of Set 1 | northam
# Processing Record 541 of Set 1 | dudinka
# City not found. Skipping...
# Processing Record 542 of Set 1 | manokwari
# Processing Record 543 of Set 1 | aykhal
# Processing Record 544 of Set 1 | mazagao
# Processing Record 545 of Set 1 | vestmanna
# Processing Record 546 of Set 1 | nuuk
# Processing Record 547 of Set 1 | aras
# Processing Record 548 of Set 1 | rosetta
# Processing Record 549 of Set 1 | saint-georges
# Processing Record 550 of Set 1 | porto-vecchio
# Processing Record 551 of Set 1 | tra vinh
# Processing Record 552 of Set 1 | tomatlan
# Processing Record 553 of Set 1 | port keats
# Processing Record 554 of Set 1 | samsun
# City not found. Skipping...
# Processing Record 555 of Set 1 | noumea
# Processing Record 556 of Set 1 | hobyo
# Processing Record 557 of Set 1 | krasnoarmeysk
# Processing Record 558 of Set 1 | saint-augustin
# Processing Record 559 of Set 1 | henties bay
# Processing Record 560 of Set 1 | boa vista
# Processing Record 561 of Set 1 | khobi
# City not found. Skipping...
# Processing Record 562 of Set 1 | taman
# Processing Record 563 of Set 1 | mayo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame(data = results)

# %%
df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    guerrero negro  27.9769 -114.0611    295.52        75           0
# 1             atasu  48.6814   71.6433    285.32        25           7
# 2        lavrentiya  65.5833 -171.0000    277.30        64          99
# 3        codrington -38.2667  141.9667    285.84        64           4
# 4         carnarvon -24.8667  113.6333    292.19        82          90
# ..              ...      ...       ...       ...       ...         ...
# 558     henties bay -22.1160   14.2845    282.51        90           1
# 559       boa vista   2.8197  -60.6733    303.14        62           0
# 560           khobi  42.3156   41.8987    293.34        96          70
# 561           taman  45.2117   36.7161    288.33        48          80
# 562            mayo  38.8876  -76.5119    301.06        88           1
#
#      Wind Speed Country        Date
# 0          9.44      MX  1631754043
# 1          1.14      KZ  1631754044
# 2          4.67      RU  1631754045
# 3          4.14      AU  1631754046
# 4          4.63      AU  1631753960
# ..          ...     ...         ...
# 558        5.47      NA  1631754354
# 559        1.54      BR  1631754355
# 560        0.84      GE  1631754355
# 561        7.05      RU  1631754356
# 562        3.13      US  1631754356
#
# [563 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
